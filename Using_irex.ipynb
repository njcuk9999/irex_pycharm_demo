# %% [markdown]
# # PyCharm - A great tool for coding in python

# %%
# lets import our module
import irex_functions as irex

# %% [markdown]
# ### 1. Jupyter notebooks are only available in Pro version
#
# However with a `umontreal.ca` account you can get a free copy!

# %% [markdown]
# ### 2. We can run jupyter note books inside pycharm!

# %%
# Add Rene
rene = irex.Professor('Rene Doyon', importance=10000)
# Add Etienne
etienne = irex.Researcher('Etienne Artigau', importance=999)
# Add Neil
neil = irex.PostDoc('Neil Cook', importance=100)
# Out:
#  Rene Doyon exists!
#
#  Etienne Artigau exists!
#
#  Neil Cook exists!

# %% [markdown]
# Including plots:

# %%
neil.show_plot()
